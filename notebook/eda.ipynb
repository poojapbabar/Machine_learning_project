# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import missingno as msno

# %%
data = pd.read_csv('adult.csv')

# %%
data
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 17211   42    Private  162003       HS-grad                9
# 17212   19          ?   52114  Some-college               10
# 17213   51  Local-gov  241843     Preschool                1
# 17214   23    Private  375871       HS-grad                9
# 17215   37    Private  186934          11th                7
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17216 entries, 0 to 17215
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              17216 non-null  int64
#  1   workclass        17216 non-null  object
#  2   fnlwgt           17216 non-null  int64
#  3   education        17216 non-null  object
#  4   educational-num  17216 non-null  int64
#  5   marital-status   17216 non-null  object
#  6   occupation       17216 non-null  object
#  7   relationship     17216 non-null  object
#  8   race             17216 non-null  object
#  9   gender           17216 non-null  object
#  10  capital-gain     17216 non-null  int64
#  11  capital-loss     17216 non-null  int64
#  12  hours-per-week   17216 non-null  int64
#  13  native-country   17216 non-null  object
#  14  income           17216 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.0+ MB

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %%
data.replace('?', np.nan, inplace = True) # Here we replace '?' with nan
data.head(20)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18               NaN  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29               NaN  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# ...

# %%
data.dropna(inplace = True)

# %%
ax = sns.countplot(data=data, x='income')
ax.set_xticklabels(['<=50K', '>50K']);
ax.set_xlabel('income');
ax.set_ylabel('Count');
ax.bar_label(ax.containers[0]);

# %%
sns.histplot(data=data,x = 'age',bins = 25,kde = True,color = 'r')
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\babar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=data,x = 'education')
plt.title('Distribution of Education level')
plt.xlabel('education level')
plt.ylabel('Count')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data=data,x = 'education', y = 'hours-per-week')
plt.title('Education vs Hours per week')
plt.xlabel('Education level')
plt.ylabel('Hours per week')
plt.xticks(rotation =45)
plt.show()

# %%
sns.countplot(data=data,x = 'gender')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=data, x='income', hue='gender', multiple='stack')
plt.title('Salary Distribution by Gender')
plt.xlabel('income')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\babar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import plotly.express as px
import plotly.graph_objects as go
import altair as alt

# %%
px.bar(data['education'].value_counts(), x=data['education'].unique(), y=data['education'].value_counts(), labels={'x':'Education Level', 'y':'Count'}, title='Distribution of Education Levels')

# %%
fig = px.scatter(data, x='capital-gain', y='capital-loss', color='income', title='Capital Gain vs. Capital Loss')
fig.show()

# %%
plt.figure(figsize=(8, 8))
data['gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
fig = px.bar(data, x='occupation', title='Occupation Distribution')
fig.show()

# %%
# Plot 16: Matplotlib - Line Plot
plt.figure(figsize=(10, 6))
data.groupby('education')['hours-per-week'].mean().plot(kind='line', marker='o')
plt.title('Average Hours per Week by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Hours per Week')
plt.xticks(rotation=45)
plt.show()

# %%
# Plot 15: Plotly - Box Plot
fig = px.box(data, x='race', y='age', color='income', title='Age Distribution by Race')
fig.show()

# %%
# # Plot 17: Seaborn - Swarm Plot
# plt.figure(figsize=(10, 6))
# sns.swarmplot(x='income', y='age', data=data)
# plt.title('Age Distribution by Salary')
# plt.xlabel('Salary')
# plt.ylabel('Age')
# plt.show()
